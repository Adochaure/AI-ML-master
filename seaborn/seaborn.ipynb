# %%
#Seaborn -> is high level data visulaization library built top on matplotlib

#Usage 
import seaborn as sns
import matplotlib.pyplot as plt

x = [1,2,3,456]
y = [4,6,9,12]

sns.scatterplot(x=x, y=y)
plt.show()

# %%
import seaborn as sns  
import matplotlib.pyplot as plt  
# Load example dataset  
tips = sns.load_dataset("tips")  

# Scatter plot of total bill vs tip  
sns.scatterplot(data=tips, x="total_bill", y="tip", hue="day", style="sex", size="size") 
plt.title("Tips Scatter Plot")  
plt.show()

# %%
# Line Plots 
# Example dataset  
data = sns.load_dataset("tips")  
# Line plot: average tip by total bill  
sns.lineplot(data=data, x="total_bill", y="tip")  
plt.title ("Line Plot: Total Bill vs Tip")  
plt.show()

# %%
# Scatter plot  
sns.scatterplot(data=data, x="total_bill", y="tip")  
plt.title("Scatter Plot: Total Bill vs Tip")  
plt.show()

# %%
#BAR plot
tips = sns.load_dataset("tips")  
sns.barplot(data=tips, x="day", y="total_bill", hue="sex") 
plt.title("Average Total Bill per Day by Sex")  
plt.show()

# %%
#box plot
sns.boxplot(data=tips, x="day", y="total_bill", hue="sex")  
plt.title("Box Plot of Total Bill by Day and Sex")  
plt.show()

# %%
#Histogram
tips = sns.load_dataset("tips")  
sns.histplot(data=tips, x="total_bill", bins=10, kde=False) 
plt.title("Histogram of Total Bill")  
plt.show()

# %%
# Example: correlation matrix of tips dataset  
tips = sns.load_dataset("tips")  
corr = tips.corr() # correlation between numerical columns  
sns.heatmap (corr, annot=True, cmap="coolwarm")  
plt.title("Correlation Heatmap")  
plt.show() 
#Heat map
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 3
#       1 # Example: correlation matrix of tips dataset
#       2 tips = sns.load_dataset("tips")
# ----> 3 corr = tips.corr() # correlation between numerical columns
#       4 sns.heatmap (corr, annot=True, cmap="coolwarm")
#       5 plt.title("Correlation Heatmap")
#
# File c:\Users\ADITYA\anaconda3\Lib\site-packages\pandas\core\frame.py:11076, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11074 cols = data.columns
#   11075 idx = cols.copy()
# > 11076 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11078 if method == "pearson":
#   11079     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File c:\Users\ADITYA\anaconda3\Lib\site-packages\pandas\core\frame.py:2002, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    2000 if dtype is not None:
#    2001     dtype = np.dtype(dtype)
# -> 2002 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    2003 if result.dtype is not dtype:
#    2004     result = np.asarray(result, dtype=dtype)
#
# File c:\Users\ADITYA\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:1713, in BlockManager.as_array(self, dtype, copy, na_value)
#    1711         arr.flags.writeable = False
#    1712 else:
# -> 1713     arr = self._interleave(dtype=dtype, na_value=na_value)
#    1714     # The underlying data was copied within _interleave, so no need
#    1715     # to further copy if copy=True or setting na_value
#    1717 if na_value is lib.no_default:
#
# File c:\Users\ADITYA\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:1766, in BlockManager._interleave(self, dtype, na_value)
#    1760 rl = blk.mgr_locs
#    1761 if blk.is_extension:
#    1762     # Avoid implicit conversion of extension blocks to object
#    1763
#    1764     # error: Item "ndarray" of "Union[ndarray, ExtensionArray]" has no
#    1765     # attribute "to_numpy"
# -> 1766     arr = blk.values.to_numpy(  # type: ignore[union-attr]
#    1767         dtype=dtype,
#    1768         na_value=na_value,
#    1769     )
#    1770 else:
#    1771     arr = blk.get_values(dtype)
#
# File c:\Users\ADITYA\anaconda3\Lib\site-packages\pandas\core\arrays\base.py:568, in ExtensionArray.to_numpy(self, dtype, copy, na_value)
#     539 def to_numpy(
#     540     self,
#     541     dtype: npt.DTypeLike | None = None,
#     542     copy: bool = False,
#     543     na_value: object = lib.no_default,
#     544 ) -> np.ndarray:
#     545     """
#     546     Convert to a NumPy ndarray.
#     547
#    (...)    566     numpy.ndarray
#     567     """
# --> 568     result = np.asarray(self, dtype=dtype)
#     569     if copy or na_value is not lib.no_default:
#     570         result = result.copy()
#
# File c:\Users\ADITYA\anaconda3\Lib\site-packages\pandas\core\arrays\_mixins.py:81, in ravel_compat.<locals>.method(self, *args, **kwargs)
#      78 @wraps(meth)
#      79 def method(self, *args, **kwargs):
#      80     if self.ndim == 1:
# ---> 81         return meth(self, *args, **kwargs)
#      83     flags = self._ndarray.flags
#      84     flat = self.ravel("K")
#
# File c:\Users\ADITYA\anaconda3\Lib\site-packages\pandas\core\arrays\categorical.py:1692, in Categorical.__array__(self, dtype, copy)
#    1686 ret = take_nd(self.categories._values, self._codes)
#    1687 # When we're a Categorical[ExtensionArray], like Interval,
#    1688 # we need to ensure __array__ gets all the way to an
#    1689 # ndarray.
#    1690
#    1691 # `take_nd` should already make a copy, so don't force again.
# -> 1692 return np.asarray(ret, dtype=dtype)
#
# ValueError: could not convert string to float: 'No'
